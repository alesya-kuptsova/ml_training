# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('C:\\Users\\Alesya\\Desktop\\kupa_lab1\\training.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#      class    GLCM_pan  Mean_Green    Mean_Red    Mean_NIR     SD_pan
# 0        w  120.362774  205.500000  119.395349  416.581395  20.676318
# 1        w  124.739583  202.800000  115.333333  354.333333  16.707151
# 2        w  134.691964  199.285714  116.857143  477.857143  22.496712
# 3        w  127.946309  178.368421   92.368421  278.473684  14.977453
# 4        w  135.431548  197.000000  112.690476  532.952381  17.604193
# 5        w  118.347962  226.150000  138.850000  608.900000  29.072797
# 6        w  135.436282  184.500000   95.142857  309.190476  13.055264
# 7        w  121.169643  226.000000  146.214286  595.571429  22.808542
# 8        w  131.127161  232.784314  144.588235  563.843137  11.948563
# 9        w  134.498092  210.212121  116.909091  594.848485  27.937685
# 10       w  131.164773  206.681818  114.727273  483.045455  22.903544
# 11       w  136.095960  201.400000  111.400000  444.600000  16.553622
# ...

# %%
print(data)
# Out:
#      class    GLCM_pan  Mean_Green    Mean_Red    Mean_NIR     SD_pan
# 0        w  120.362774  205.500000  119.395349  416.581395  20.676318
# 1        w  124.739583  202.800000  115.333333  354.333333  16.707151
# 2        w  134.691964  199.285714  116.857143  477.857143  22.496712
# 3        w  127.946309  178.368421   92.368421  278.473684  14.977453
# 4        w  135.431548  197.000000  112.690476  532.952381  17.604193
# 5        w  118.347962  226.150000  138.850000  608.900000  29.072797
# 6        w  135.436282  184.500000   95.142857  309.190476  13.055264
# 7        w  121.169643  226.000000  146.214286  595.571429  22.808542
# 8        w  131.127161  232.784314  144.588235  563.843137  11.948563
# 9        w  134.498092  210.212121  116.909091  594.848485  27.937685
# 10       w  131.164773  206.681818  114.727273  483.045455  22.903544
# 11       w  136.095960  201.400000  111.400000  444.600000  16.553622
# ...

# %%
data.head()
# Out:
#   class    GLCM_pan  Mean_Green    Mean_Red    Mean_NIR     SD_pan
# 0     w  120.362774  205.500000  119.395349  416.581395  20.676318
# 1     w  124.739583  202.800000  115.333333  354.333333  16.707151
# 2     w  134.691964  199.285714  116.857143  477.857143  22.496712
# 3     w  127.946309  178.368421   92.368421  278.473684  14.977453
# 4     w  135.431548  197.000000  112.690476  532.952381  17.604193

# %%
#мы помним что:
#class: 'w' (больные деревья), 'n' (все другие растительные покровы) 
#GLCM_Pan: средняя текстура GLCM (диапазон панорамирования) 
#Mean_G: среднее значение зеленого 
#Mean_R: среднее значение красного 
#Mean_NIR: среднее значение NIR 
#SD_Pan: стандартное отклонение (диапазон панорамирования )

# %%
data.tail()
# Out:
#      class    GLCM_pan  Mean_Green    Mean_Red    Mean_NIR     SD_pan
# 4334     n  111.568773  203.588235   93.264706  403.735294  26.512777
# 4335     n  125.435240  206.394161   93.058394  512.270073  33.466060
# 4336     n  132.123859  465.343750  295.333333  499.250000  38.762967
# 4337     n  124.469536  215.152632   98.484211  675.915789  28.506542
# 4338     n  125.171928  559.048000  365.968000  439.272000  15.392322

# %%
print(data.shape)
print(data.columns)
# Out:
# (4339, 6)
# Index(['class', 'GLCM_pan', 'Mean_Green', 'Mean_Red', 'Mean_NIR', 'SD_pan'], dtype='object')

# %%
#data.columns = []

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4339, step=1)

# %%
data.at[4, 'Mean_Green']
# Out:
# 197.0

# %%
data['Mean_Green']
# Out:
# 0       205.500000
# 1       202.800000
# 2       199.285714
# 3       178.368421
# 4       197.000000
# 5       226.150000
# 6       184.500000
# 7       226.000000
# 8       232.784314
# 9       210.212121
# 10      206.681818
# 11      201.400000
# 12      230.560976
# 13      213.107143
# 14      191.621622
# 15      213.666667
# 16      201.358491
# 17      199.744681
# 18      221.750000
# 19      220.111111
# 20      192.232877
# 21      226.673469
# 22      188.984000
# 23      170.363636
# 24      164.625000
# 25      189.896552
# 26      222.392157
# 27      174.000000
# 28      199.750000
# 29      180.741936
#            ...
# 4309    208.571429
# 4310    202.884615
# 4311    299.369127
# 4312    200.533333
# 4313    369.000000
# 4314    299.033898
# 4315    366.862745
# 4316    216.795918
# 4317    235.000000
# 4318    204.947712
# 4319    328.547739
# 4320    189.761111
# 4321    224.589286
# 4322    285.750000
# 4323    231.481752
# 4324    206.655172
# ...

# %%
data['Mean_Green'][4]
# Out:
# 197.0

# %%
data['Mean_Green'].dtype.name
# Out:
# 'float64'

# %%
type(data['class'][4])
# Out:
# str

# %%
type(data['Mean_Green'])
# Out:
# pandas.core.series.Series

# %%
data[['class', 'Mean_Green']].head()
# Out:
#   class  Mean_Green
# 0     w  205.500000
# 1     w  202.800000
# 2     w  199.285714
# 3     w  178.368421
# 4     w  197.000000

# %%
data.describe()
# Out:
#           GLCM_pan   Mean_Green     Mean_Red     Mean_NIR       SD_pan
# count  4339.000000  4339.000000  4339.000000  4339.000000  4339.000000
# mean    126.831298   233.906908   117.292439   534.104683    24.924588
# std      13.735836    60.757687    60.711159   154.495500    11.008303
# min       0.000000   164.625000    59.142857    86.500000     0.000000
# 25%     118.589080   206.000000    91.975244   422.875000    18.009143
# 50%     127.479167   221.454545   101.727273   528.500000    23.612444
# 75%     135.043591   241.791304   116.866071   643.087037    29.899148
# max     183.281250   955.714286   746.333333  1005.516129   156.508431

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#             GLCM_pan  Mean_Green  Mean_Red  Mean_NIR    SD_pan
# GLCM_pan    1.000000   -0.122384 -0.107166 -0.094263 -0.065023
# Mean_Green -0.122384    1.000000  0.964682  0.223518  0.246103
# Mean_Red   -0.107166    0.964682  1.000000  0.121230  0.254383
# Mean_NIR   -0.094263    0.223518  0.121230  1.000000  0.120276
# SD_pan     -0.065023    0.246103  0.254383  0.120276  1.000000

# %%
plt.plot(data['class'], data['Mean_Green'], 'o', alpha = 0.05)
plt.xlabel('class')
plt.ylabel('Mean_Green')
plt.title('class vs Mean_Green')
pass

# %%
plt.plot(data['Mean_Green'], data['Mean_Red'], 'o', alpha = 0.05)
plt.xlabel('Mean_Green')
plt.ylabel('Mean_Red')
plt.title('Mean_Green vs Mean_Red')
pass

# %%
data['Mean_Green'] <= 200
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17       True
# 18      False
# 19      False
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 4309    False
# 4310    False
# 4311    False
# 4312    False
# 4313    False
# 4314    False
# 4315    False
# 4316    False
# 4317    False
# 4318    False
# 4319    False
# 4320     True
# 4321    False
# 4322    False
# 4323    False
# 4324    False
# 4325     True
# 4326    False
# 4327    False
# 4328    False
# 4329    False
# 4330    False
# 4331    False
# 4332    False
# 4333    False
# 4334    False
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# ...

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['class']
# ['GLCM_pan', 'Mean_Green', 'Mean_Red', 'Mean_NIR', 'SD_pan']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# class ['w' 'n']

# %%
data.median(axis = 0)
# Out:
# GLCM_pan      127.479167
# Mean_Green    221.454545
# Mean_Red      101.727273
# Mean_NIR      528.500000
# SD_pan         23.612444
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# GLCM_pan      4339
# Mean_Green    4339
# Mean_Red      4339
# Mean_NIR      4339
# SD_pan        4339
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# class    4339
# dtype: int64

# %%
data.describe(include = [object])
# Out:
#        class
# count   4339
# unique     2
# top        n
# freq    4265

# %%
data_describe = data.describe(include = [object])

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['class'] []

# %%
data['class'].unique()
# Out:
# array(['w', 'n'], dtype=object)

# %%
data.at[data['class'] == 'n', 'class'] = 0
data.at[data['class'] == 'w', 'class'] = 1
data['class'].describe()
# Out:
# count    4339.000000
# mean        0.017055
# std         0.129490
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: class, dtype: float64

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#           GLCM_pan   Mean_Green     Mean_Red     Mean_NIR       SD_pan
# count  4339.000000  4339.000000  4339.000000  4339.000000  4339.000000
# mean    126.831298   233.906908   117.292439   534.104683    24.924588
# std      13.735836    60.757687    60.711159   154.495500    11.008303
# min       0.000000   164.625000    59.142857    86.500000     0.000000
# 25%     118.589080   206.000000    91.975244   422.875000    18.009143
# 50%     127.479167   221.454545   101.727273   528.500000    23.612444
# 75%     135.043591   241.791304   116.866071   643.087037    29.899148
# max     183.281250   955.714286   746.333333  1005.516129   156.508431

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#            GLCM_pan    Mean_Green      Mean_Red      Mean_NIR        SD_pan
# count  4.339000e+03  4.339000e+03  4.339000e+03  4.339000e+03  4.339000e+03
# mean  -1.533363e-15 -1.193156e-14 -4.238242e-15 -1.071589e-14  5.207404e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.233606e+00 -1.140299e+00 -9.578071e-01 -2.897202e+00 -2.264163e+00
# 25%   -6.000521e-01 -4.593148e-01 -4.170106e-01 -7.199542e-01 -6.282026e-01
# 50%    4.716630e-02 -2.049512e-01 -2.563806e-01 -3.627732e-02 -1.191959e-01
# 75%    5.978735e-01  1.297679e-01 -7.022879e-03  7.054079e-01  4.518916e-01
# max    4.109684e+00  1.188010e+01  1.036121e+01  3.051296e+00  1.195315e+01

# %%
data.describe()
# Out:
#              class     GLCM_pan   Mean_Green     Mean_Red     Mean_NIR  \
# count  4339.000000  4339.000000  4339.000000  4339.000000  4339.000000
# mean      0.017055   126.831298   233.906908   117.292439   534.104683
# std       0.129490    13.735836    60.757687    60.711159   154.495500
# min       0.000000     0.000000   164.625000    59.142857    86.500000
# 25%       0.000000   118.589080   206.000000    91.975244   422.875000
# 50%       0.000000   127.479167   221.454545   101.727273   528.500000
# 75%       0.000000   135.043591   241.791304   116.866071   643.087037
# max       1.000000   183.281250   955.714286   746.333333  1005.516129
#
#             SD_pan
# count  4339.000000
# mean     24.924588
# std      11.008303
# min       0.000000
# 25%      18.009143
# 50%      23.612444
# 75%      29.899148
# max     156.508431

# %%
X = data.drop(('class'), axis = 1) # выбрасываем столбец 'class'
y = data['class']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['GLCM_pan', 'Mean_Green', 'Mean_Red', 'Mean_NIR', 'SD_pan'], dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (4339, 5)
# (4339,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 3037 1302

# %%
# используем метод близжайших соседей (kNN):
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0135001646361541 0.014592933947772658

# %%
 # попробуем 2 способ нахождения ошибки:
err_test = 1 - knn.score(X_test, y_test)

# %%
err_test
# Out:
# 0.014592933947772613

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1276    0]
#  [  19    7]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %%
# Подберем параметры:
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.005597629239381008 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.008448540706605223

# %%
# Попробуем Extremely Random Forest:
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.009984639016897081
